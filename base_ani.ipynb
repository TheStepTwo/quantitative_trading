# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings; 
import easyquotation
import json
import requests

# %%
import requests
headers = {
    'Content-Type': 'application/json'
}

requestResponse = requests.get("https://api.tiingo.com/tiingo/daily/aapl/prices?startDate=2019-01-02&token=efef9b36ec109640f46b288fb6586169f124bb59", headers=headers)
# print(requestResponse.json())
df = pd.DataFrame.from_dict(requestResponse.json())
df
# Out:
#        adjClose     adjHigh      adjLow     adjOpen  adjVolume   close  \
# 0    155.201765  156.115757  151.575280  152.223920   37039737  157.92
# 1    139.742522  143.211761  139.555792  141.501711   91312195  142.19
# 2    145.708040  145.992950  141.324809  142.042244   58607070  148.26
# 3    145.383720  146.268229  143.388662  146.140467   54777764  147.93
# 4    148.155181  149.206763  145.963565  146.985664   41025314  150.75
# 5    150.671116  151.870116  147.054459  148.685886   45099081  153.31
# 6    151.152682  151.319756  148.263287  149.875058   35780670  153.80
# 7    149.668673  151.054403  148.902099  150.248517   27023241  152.29
# 8    147.418090  148.666230  146.651516  148.253459   32439186  150.00
# 9    150.435247  150.749739  147.467229  147.683443   28710324  153.07
# 10   152.273059  153.196879  150.366452  150.445075   30569706  154.94
# 11   153.177223  154.946241  150.621977  151.545797   29821160  155.86
# ...
